# %%
# !pip install python-dotenv

# %%
import os
from dotenv import load_dotenv
PATH = "/content/drive/MyDrive/Projects/Gen AI/"
Project = "Building-System-with-the-ChatGPT-API"
os.chdir(PATH)
repo_url = os.path.join("https://github.com/Siddartha-Kodaboina", Project)

# %%
# create an env file here

# %% [markdown]
# %%writefile "/content/drive/MyDrive/Projects/Gen AI/Building System with ChatGPT API/.env"
#
# GITHUB_USERNAME="Siddartha-Kodaboina"
#
# GITHUB_API_KEY="Access token"

# %%
env_path = os.path.join(PATH, Project, '.env')
load_dotenv(dotenv_path=env_path)

api_key = os.getenv('GITHUB_API_KEY')
user_name = os.getenv('GITHUB_USERNAME')

# %%
# !git clone {repo_url}
# Out:
# Cloning into 'Building-System-with-the-ChatGPT-API'...
# remote: Enumerating objects: 5, done.
# remote: Counting objects: 100% (5/5), done.
# remote: Compressing objects: 100% (4/4), done.
# remote: Total 5 (delta 0), reused 0 (delta 0), pack-reused 0
# Receiving objects: 100% (5/5), done.

# %%
os.chdir(Project)

# %%
print(os.getcwd())
# Out:
# /content/drive/MyDrive/Projects/Gen AI/Building-System-with-the-ChatGPT-API

# %%
for file in os.listdir():
    print(file, os.getcwd())
# Out:
# index.ipynb /content/drive/My Drive/Projects/Gen AI/Building-System-with-the-ChatGPT-API
# .git /content/drive/My Drive/Projects/Gen AI/Building-System-with-the-ChatGPT-API
# .gitignore /content/drive/My Drive/Projects/Gen AI/Building-System-with-the-ChatGPT-API
# LICENSE /content/drive/My Drive/Projects/Gen AI/Building-System-with-the-ChatGPT-API
# README.md /content/drive/My Drive/Projects/Gen AI/Building-System-with-the-ChatGPT-API
# .env /content/drive/My Drive/Projects/Gen AI/Building-System-with-the-ChatGPT-API

# %%
# Add the changes
# !git add "index.ipynb"

# Commit the changes
# !git config --global user.email "stevesiddu49@example.com"
# !git config --global user.name "Siddartha-Kodaboina"
# !git commit -m "Add notebook from Google Colab"

# Push the changes
# !git push
